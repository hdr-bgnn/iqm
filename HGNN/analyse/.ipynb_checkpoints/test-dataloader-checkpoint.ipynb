# %% [markdown]
# imports

# %%
import dataLoader
from configParser import ConfigParser

# %% [markdown]
# params

# %%
# defining global variables
experimentName = "test_22987_suffix50_11_CNN2_differentConfig_softmax_multi"
experimentName2 = None # "test_22987_suffix50_11_splitTest_3"
list_of_sizes_of_interest = [] # 20,50,100

params = ConfigParser(experimentName).read()
print(params)
if experimentName2 is not None:
    params2 = ConfigParser(experimentName2).read()
    print(params2)
# Out:
# {'image_path': '/data/BGNN_data/INHS_cropped', 'suffix': '50_11', 'training_count': 0.64, 'validation_count': 0.16, 'imageDimension': 224, 'n_channels': 3, 'augmentation': False, 'batchSize': 550, 'n_epochs': 1000, 'learning_rate': 0.0001, 'numOfTrials': 3, 'patience': 100, 'useHeirarchy': True, 'useRelu': True, 'downsample': True, 'downsampleOutput': 50, 'takeFromIntermediate': True, 'takeFromIntermediateOutput': 50, 'fc_layers': 1, 'useAdam': True, 'resnet': '18', 'normalize': False, 'softmax': False}

# %% [markdown]
# pre-defined strings

# %%
cleaned_species_csv_fileName = "cleaned_metadata.csv"
species_csv_fileName_header = "fileName"
species_csv_scientificName_header = "scientificName"
species_csv_Genus_header = "Genus"
species_csv_Family_header = "Family"
image_subpath = "images"
species_csv_usedColumns = [species_csv_fileName_header,
                          species_csv_scientificName_header,
                          species_csv_Genus_header,
                          species_csv_Family_header]

# %% [markdown]
# Create dataset

# %%
datasetManager = dataLoader.datasetManager(experimentName)
datasetManager.updateParams(params)
dataset = datasetManager.getDataset()
# Out:
# file /data/BGNN_data/INHS_cropped/50_11/test_22987_suffix50_11_CNN2_differentConfig_softmax_multi/tc0.640000_vc0.160000_d224_c3_augFalse_nFalse/dataset.pkl read

# %% [markdown]
# try to reload dataset

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

dataset = datasetManager.getDataset()
speciesList = dataset.getSpeciesList()
numberOfSpecies = len(speciesList)
print("Number of species = ", numberOfSpecies)
genusList = dataset.getGenusList()
numberOfGenus = len(genusList)
print("Number of species = ", numberOfGenus)
# Out:
# Number of species =  11
# Number of species =  5

# %%
# parameter
example_index = 10

import torch

fig, axes = plt.subplots(1, 1, figsize=(15, 2.5), dpi= 300)
axes.set_xlabel("example")
augmentation, normalization = dataset.toggle_image_loading(augmentation=False, normalization=False)
speciesExample = dataset[example_index]['image'].squeeze()
dataset.toggle_image_loading(augmentation, normalization)
augmentation, normalization = dataset.toggle_image_loading(augmentation=True, normalization=False)
speciesExample2 = dataset[example_index]['image'].squeeze()
dataset.toggle_image_loading(augmentation, normalization)

n_channels = params["n_channels"]
channel = 2 if n_channels != 1 else 1
stitchedImage = torch.cat((speciesExample, speciesExample2), channel)

if n_channels != 1:
    stitchedImage = stitchedImage.permute(1, 2, 0)
axes.set_xticks([])
axes.set_yticks([])
axes.imshow(stitchedImage.cpu().detach().numpy())

# %% [markdown]
# Try to reload dataset with changed params

# %%
if experimentName2 is not None:
    datasetManager = dataLoader3.datasetManager(experimentName2)
    datasetManager.updateParams(params2)
    dataset = datasetManager.getDataset()
    numberOfSpecies = len(speciesList)
    print("Number of species = ", numberOfSpecies)

# %% [markdown]
# Try same experiment but different dataset params

# %%
if experimentName2 is not None:
    params2['patience'] = 1000
    print(params2)
    datasetManager.updateParams(params2)
    dataset = datasetManager.getDataset()
    numberOfSpecies = len(speciesList)
    print("Number of species = ", numberOfSpecies)

# %% [markdown]
# Get old dataset back

# %%
dataset = datasetManager.getDataset()

# %%
datasetManager = dataLoader.datasetManager(experimentName)
datasetManager.updateParams(params)
dataset = datasetManager.getDataset()
print(speciesList)
# Out:
# file /data/BGNN_data/INHS_cropped/50_11/test_22987_suffix50_11_CNN2_differentConfig_softmax_multi/tc0.640000_vc0.160000_d224_c3_augFalse_nFalse/dataset.pkl read
# ['Lepomis cyanellus', 'Lepomis auritus', 'Carassius auratus', 'Cyprinus carpio', 'Esox americanus', 'Esox lucius', 'Noturus gyrinus', 'Noturus exilis', 'Noturus flavus', 'Noturus eleutherus', 'Noturus insignis']

# %% [markdown]
# Data Loader

# %%
train_loader, validation_loader, test_loader = datasetManager.getLoaders()

trainingFileNames = []
valFileNames = []
testFileNames = []

for batch in train_loader:
    print(batch['species'])
    print(batch['fileName'])
# Out:
# file /data/BGNN_data/INHS_cropped/50_11/test_22987_suffix50_11_CNN2_differentConfig_softmax_multi/trainingIndex.pkl written
# file /data/BGNN_data/INHS_cropped/50_11/test_22987_suffix50_11_CNN2_differentConfig_softmax_multi/valIndex.pkl written
# file /data/BGNN_data/INHS_cropped/50_11/test_22987_suffix50_11_CNN2_differentConfig_softmax_multi/testIndex.pkl written
# file /data/BGNN_data/INHS_cropped/50_11/test_22987_suffix50_11_CNN2_differentConfig_softmax_multi/tc0.640000_vc0.160000_d224_c3_augFalse_nFalse/trainingLoader.pkl written
# file /data/BGNN_data/INHS_cropped/50_11/test_22987_suffix50_11_CNN2_differentConfig_softmax_multi/tc0.640000_vc0.160000_d224_c3_augFalse_nFalse/valLoader.pkl written
# file /data/BGNN_data/INHS_cropped/50_11/test_22987_suffix50_11_CNN2_differentConfig_softmax_multi/tc0.640000_vc0.160000_d224_c3_augFalse_nFalse/testLoader.pkl written
# tensor([10,  2, 10,  5,  9,  1,  6,  4, 10,  1,  8,  8,  7, 10,  0,  6,  3,  0,
#          4,  0,  6,  0,  2,  2,  1,  3, 10, 10,  7,  1,  5, 10,  3,  7,  8,  3,
#          1, 10,  0,  3,  8,  0,  5,  8,  5,  8,  6,  1,  1,  5,  5,  1,  0,  9,
#          8,  2,  4,  0, 10,  1,  3,  9, 10,  5, 10,  8,  3,  1,  8,  6,  7,  4,
#          8,  2,  1,  3,  3,  9,  2,  3,  8,  6, 10,  6,  4,  0,  8,  4,  1,  0,
#         10,  2,  7,  5,  6,  1,  9,  4,  3,  0,  6,  9,  5,  0,  0, 10,  5,  3,
#          7,  6,  4,  7,  1,  9,  3,  4,  3,  2,  5,  0,  1,  1,  6,  9,  4,  0,
#          9,  3,  6,  8,  0,  7,  6,  6,  0,  9,  1,  8,  1,  6,  4,  9,  1,  2,
#          7,  2,  6,  7,  3,  8,  3,  0,  9,  8,  6,  0,  6,  7,  4,  8,  7,  5,
#          9,  2,  3,  4,  4,  3,  1,  4,  7,  1,  6,  6, 10,  5,  7,  3, 10,  7,
#          7,  8,  5,  4,  7,  9,  4,  5,  1,  5, 10,  4,  3,  9,  6,  1,  3,  2,
#          9,  5,  3,  9,  4,  9,  0,  2,  7,  6,  5,  9, 10,  1,  1,  9,  8, 10,
#          9,  5,  9,  5,  7,  3,  6,  7,  2,  4,  3,  1,  2,  0,  5,  9,  2,  4,
#          0,  8,  4,  3,  2,  5,  7,  3,  7,  4,  0,  5,  5,  8,  7,  4,  7,  0,
#          2,  8,  1, 10, 10,  6, 10,  2, 10,  1,  3,  8,  5,  5, 10,  0,  2,  3,
#          9,  1,  7,  2,  8,  2,  9, 10,  9, 10,  3,  0,  4,  9,  6,  4,  2,  2,
#          0,  4,  1,  2,  5,  2,  7,  8, 10,  1,  4,  6,  6,  9,  7,  4,  6,  7,
#          1,  8,  5,  7,  9,  8,  9,  8,  8, 10,  7,  4,  2,  2, 10,  6,  8,  2,
#         10,  0,  2,  4,  0,  3,  2,  5,  0,  6,  0,  6,  9,  4,  8,  8,  0,  5,
#          7,  5,  5, 10,  6,  7,  2, 10,  3,  9])
# ['INHS_FISH_75084.jpg', 'INHS_FISH_90762.jpg', 'INHS_FISH_64071.jpg', 'INHS_FISH_83767.jpg', 'INHS_FISH_53622.jpg', 'INHS_FISH_90219.jpg', 'INHS_FISH_105894.jpg', 'INHS_FISH_108140.jpg', 'INHS_FISH_45086.jpg', 'INHS_FISH_50076.jpg', 'INHS_FISH_98057.jpg', 'INHS_FISH_41053.jpg', 'INHS_FISH_17910.jpg', 'INHS_FISH_51439.jpg', 'INHS_FISH_96891.jpg', 'INHS_FISH_77132.jpg', 'INHS_FISH_56994.jpg', 'INHS_FISH_30228.jpg', 'INHS_FISH_58949.jpg', 'INHS_FISH_79838.jpg', 'INHS_FISH_23182.jpg', 'INHS_FISH_20690.jpg', 'INHS_FISH_006548.jpg', 'INHS_FISH_25478.jpg', 'INHS_FISH_51429.jpg', 'INHS_FISH_13056.jpg', 'INHS_FISH_75164.jpg', 'INHS_FISH_29712.jpg', 'INHS_FISH_103344.jpg', 'INHS_FISH_76300.jpg', 'INHS_FISH_4135.jpg', 'INHS_FISH_38407.jpg', 'INHS_FISH_45318.jpg', 'INHS_FISH_58391.jpg', 'INHS_FISH_85801.jpg', 'INHS_FISH_758.jpg', 'INHS_FISH_82104.jpg', 'INHS_FISH_29732.jpg', 'INHS_FISH_30573.jpg', 'INHS_FISH_102103.jpg', 'INHS_FISH_31009.jpg', 'INHS_FISH_30215.jpg', 'INHS_FISH_83749.jpg', 'INHS_FISH_109100.jpg', 'INHS_FISH_79504.jpg', 'INHS_FISH_93918.jpg', 'INHS_FISH_38018.jpg', 'INHS_FISH_90177.jpg', 'INHS_FISH_63061.jpg', 'INHS_FISH_26197.jpg', 'INHS_FISH_92612.jpg', 'INHS_FISH_47027.jpg', 'INHS_FISH_93371.jpg', 'INHS_FISH_63307.jpg', 'INHS_FISH_26400.jpg', 'INHS_FISH_026162.jpg', 'INHS_FISH_63373.jpg', 'INHS_FISH_11083.jpg', 'INHS_FISH_83522.jpg', 'INHS_FISH_51445.jpg', 'INHS_FISH_25087.jpg', 'INHS_FISH_61200.jpg', 'INHS_FISH_75234.jpg', 'INHS_FISH_91037.jpg', 'INHS_FISH_74127.jpg', 'INHS_FISH_5603.jpg', 'INHS_FISH_21342.jpg', 'INHS_FISH_51500.jpg', 'INHS_FISH_85839.jpg', 'INHS_FISH_59146.jpg', 'INHS_FISH_81563.jpg', 'INHS_FISH_5668.jpg', 'INHS_FISH_95470.jpg', 'INHS_FISH_25907.jpg', 'INHS_FISH_59564.jpg', 'INHS_FISH_57055.jpg', 'INHS_FISH_48520.jpg', 'INHS_FISH_7746.jpg', 'INHS_FISH_99722.jpg', 'INHS_FISH_32929.jpg', 'INHS_FISH_24644.jpg', 'INHS_FISH_100045.jpg', 'INHS_FISH_29741.jpg', 'INHS_FISH_917.jpg', 'INHS_FISH_2237.jpg', 'INHS_FISH_73804.jpg', 'INHS_FISH_87328.jpg', 'INHS_FISH_38979.jpg', 'INHS_FISH_74738.jpg', 'INHS_FISH_95087.jpg', 'INHS_FISH_76861.jpg', 'INHS_FISH_95122.jpg', 'INHS_FISH_47733.jpg', 'INHS_FISH_97321.jpg', 'INHS_FISH_90944.jpg', 'INHS_FISH_74358.jpg', 'INHS_FISH_73746.jpg', 'INHS_FISH_106678.jpg', 'INHS_FISH_47774.jpg', 'INHS_FISH_3491.jpg', 'INHS_FISH_56007.jpg', 'INHS_FISH_53366.jpg', 'INHS_FISH_99125.jpg', 'INHS_FISH_2401.jpg', 'INHS_FISH_68715.jpg', 'INHS_FISH_58981.jpg', 'INHS_FISH_30051.jpg', 'INHS_FISH_016548.jpg', 'INHS_FISH_21622.jpg', 'INHS_FISH_6183.jpg', 'INHS_FISH_108310.jpg', 'INHS_FISH_56337.jpg', 'INHS_FISH_47068.jpg', 'INHS_FISH_9080.jpg', 'INHS_FISH_49935.jpg', 'INHS_FISH_7433.jpg', 'INHS_FISH_15857.jpg', 'INHS_FISH_73787.jpg', 'INHS_FISH_686.jpg', 'INHS_FISH_1587.jpg', 'INHS_FISH_46194.jpg', 'INHS_FISH_86895.jpg', 'INHS_FISH_17424.jpg', 'INHS_FISH_42717.jpg', 'INHS_FISH_39616.jpg', 'INHS_FISH_58723.jpg', 'INHS_FISH_94751.jpg', 'INHS_FISH_7471.jpg', 'INHS_FISH_8939.jpg', 'INHS_FISH_6497.jpg', 'INHS_FISH_50729.jpg', 'INHS_FISH_82823.jpg', 'INHS_FISH_87503.jpg', 'INHS_FISH_32540.jpg', 'INHS_FISH_98083.jpg', 'INHS_FISH_75145.jpg', 'INHS_FISH_94583.jpg', 'INHS_FISH_102495.jpg', 'INHS_FISH_87500.jpg', 'INHS_FISH_103738.jpg', 'INHS_FISH_9169.jpg', 'INHS_FISH_38458.jpg', 'INHS_FISH_46173.jpg', 'INHS_FISH_000710.jpg', 'INHS_FISH_58307.jpg', 'INHS_FISH_25217.jpg', 'INHS_FISH_126.jpg', 'INHS_FISH_81018.jpg', 'INHS_FISH_17458.jpg', 'INHS_FISH_37733.jpg', 'INHS_FISH_21758.jpg', 'INHS_FISH_96007.jpg', 'INHS_FISH_26685.jpg', 'INHS_FISH_6369.jpg', 'INHS_FISH_56382.jpg', 'INHS_FISH_105265.jpg', 'INHS_FISH_21565.jpg', 'INHS_FISH_47006.jpg', 'INHS_FISH_53152.jpg', 'INHS_FISH_429.jpg', 'INHS_FISH_62540.jpg', 'INHS_FISH_85778.jpg', 'INHS_FISH_69011.jpg', 'INHS_FISH_93340.jpg', 'INHS_FISH_12568.jpg', 'INHS_FISH_45432.jpg', 'INHS_FISH_15451.jpg', 'INHS_FISH_23133.jpg', 'INHS_FISH_68432.jpg', 'INHS_FISH_63274.jpg', 'INHS_FISH_86437.jpg', 'INHS_FISH_41171.jpg', 'INHS_FISH_92623.jpg', 'INHS_FISH_4051.jpg', 'INHS_FIS ...

# %%
for batch in validation_loader:
    print(batch['species'])
    print(batch['fileName'])
# Out:
# tensor([ 2, 10,  7,  7,  2, 10,  8,  9,  2,  0,  3,  0,  6,  8,  9,  4, 10,  9,
#          2,  9,  3,  3,  1,  0,  5,  6, 10,  5,  4,  4,  2,  5,  5,  4,  1,  8,
#          9,  4,  6,  0,  1,  2,  7,  6,  1,  8,  8, 10,  6,  4,  8, 10, 10,  0,
#          9,  3,  6,  9,  5,  7,  0,  2,  6,  7,  2,  0,  6,  8, 10,  4,  5,  1,
#          9,  7,  1,  3,  8,  3,  5,  5,  7,  4,  0,  3,  7,  1,  3,  1])
# ['INHS_FISH_025698.jpg', 'INHS_FISH_29618.jpg', 'INHS_FISH_85012.jpg', 'INHS_FISH_89702.jpg', 'INHS_FISH_33737.jpg', 'INHS_FISH_27267.jpg', 'INHS_FISH_12762.jpg', 'INHS_FISH_53547.jpg', 'INHS_FISH_5124.jpg', 'INHS_FISH_2930.jpg', 'INHS_FISH_19369.jpg', 'INHS_FISH_98964.jpg', 'INHS_FISH_99351.jpg', 'INHS_FISH_23032.jpg', 'INHS_FISH_59010.jpg', 'INHS_FISH_84741.jpg', 'INHS_FISH_49738.jpg', 'INHS_FISH_101493.jpg', 'INHS_FISH_88453.jpg', 'INHS_FISH_64079.jpg', 'INHS_FISH_20480.jpg', 'INHS_FISH_103780.jpg', 'INHS_FISH_59426.jpg', 'INHS_FISH_93197.jpg', 'INHS_FISH_91796.jpg', 'INHS_FISH_59719.jpg', 'INHS_FISH_50082.jpg', 'INHS_FISH_4325.jpg', 'INHS_FISH_11536.jpg', 'INHS_FISH_96417.jpg', 'INHS_FISH_25964.jpg', 'INHS_FISH_85738.jpg', 'INHS_FISH_24815.jpg', 'INHS_FISH_95180.jpg', 'INHS_FISH_46332.jpg', 'INHS_FISH_41119.jpg', 'INHS_FISH_55653.jpg', 'INHS_FISH_15323.jpg', 'INHS_FISH_105980.jpg', 'INHS_FISH_23986.jpg', 'INHS_FISH_75215.jpg', 'INHS_FISH_59327.jpg', 'INHS_FISH_104982.jpg', 'INHS_FISH_29582.jpg', 'INHS_FISH_59400.jpg', 'INHS_FISH_36377.jpg', 'INHS_FISH_11927.jpg', 'INHS_FISH_46291.jpg', 'INHS_FISH_100058.jpg', 'INHS_FISH_12930.jpg', 'INHS_FISH_42898.jpg', 'INHS_FISH_50043.jpg', 'INHS_FISH_83472.jpg', 'INHS_FISH_59772.jpg', 'INHS_FISH_73690.jpg', 'INHS_FISH_40695.jpg', 'INHS_FISH_2198.jpg', 'INHS_FISH_9752.jpg', 'INHS_FISH_25235.jpg', 'INHS_FISH_18094.jpg', 'INHS_FISH_46448.jpg', 'INHS_FISH_014466.jpg', 'INHS_FISH_33863.jpg', 'INHS_FISH_108764.jpg', 'INHS_FISH_026757.jpg', 'INHS_FISH_100636.jpg', 'INHS_FISH_108535.jpg', 'INHS_FISH_10536.jpg', 'INHS_FISH_75225.jpg', 'INHS_FISH_88301.jpg', 'INHS_FISH_295.jpg', 'INHS_FISH_88262.jpg', 'INHS_FISH_93884.jpg', 'INHS_FISH_108714.jpg', 'INHS_FISH_59381.jpg', 'INHS_FISH_90518.jpg', 'INHS_FISH_57524.jpg', 'INHS_FISH_100521.jpg', 'INHS_FISH_2088.jpg', 'INHS_FISH_99106.jpg', 'INHS_FISH_83999.jpg', 'INHS_FISH_47791.jpg', 'INHS_FISH_4798.jpg', 'INHS_FISH_23153.jpg', 'INHS_FISH_80509.jpg', 'INHS_FISH_75276.jpg', 'INHS_FISH_017196.jpg', 'INHS_FISH_68672.jpg']

# %%
for batch in test_loader:
    print(batch['species'])
    print(batch['fileName'])
# Out:
# tensor([ 0,  8,  5, 10,  6,  0,  2,  5,  4,  5,  3,  3,  9, 10,  6,  4,  2,  2,
#          0,  1,  2,  7,  1,  9,  6,  0,  1,  6,  9, 10,  1,  5,  2,  8, 10,  3,
#          9,  6,  9,  9,  7,  1,  5,  4,  0,  8,  2,  2, 10,  8,  3,  2,  0,  5,
#          6,  7,  1,  4,  7, 10,  8,  3,  0,  4,  4,  4,  7,  1,  4,  1,  2, 10,
#         10,  5,  0,  7,  7,  6,  6,  7,  3,  0,  2,  5,  9,  8,  9,  7,  3,  5,
#          5,  1,  6,  4,  8,  8,  3,  9, 10,  3,  3, 10,  4,  8,  7,  0,  8,  6,
#          1,  9])
# ['INHS_FISH_51437.jpg', 'INHS_FISH_102623.jpg', 'INHS_FISH_4297.jpg', 'INHS_FISH_29612.jpg', 'INHS_FISH_85232.jpg', 'INHS_FISH_3026.jpg', 'INHS_FISH_4916.jpg', 'INHS_FISH_26975.jpg', 'INHS_FISH_63090.jpg', 'INHS_FISH_64109.jpg', 'INHS_FISH_7761.jpg', 'INHS_FISH_89664.jpg', 'INHS_FISH_9867.jpg', 'INHS_FISH_74146.jpg', 'INHS_FISH_7021.jpg', 'INHS_FISH_95243.jpg', 'INHS_FISH_25607.jpg', 'INHS_FISH_29399.jpg', 'INHS_FISH_51409.jpg', 'INHS_FISH_62927.jpg', 'INHS_FISH_75313.jpg', 'INHS_FISH_86350.jpg', 'INHS_FISH_59062.jpg', 'INHS_FISH_89189.jpg', 'INHS_FISH_96502.jpg', 'INHS_FISH_98732.jpg', 'INHS_FISH_90210.jpg', 'INHS_FISH_12572.jpg', 'INHS_FISH_2510.jpg', 'INHS_FISH_90148.jpg', 'INHS_FISH_51885.jpg', 'INHS_FISH_3731.jpg', 'INHS_FISH_101143.jpg', 'INHS_FISH_13297.jpg', 'INHS_FISH_32332.jpg', 'INHS_FISH_50300.jpg', 'INHS_FISH_11445.jpg', 'INHS_FISH_57607.jpg', 'INHS_FISH_9423.jpg', 'INHS_FISH_2410.jpg', 'INHS_FISH_74241.jpg', 'INHS_FISH_28597.jpg', 'INHS_FISH_104808.jpg', 'INHS_FISH_98495.jpg', 'INHS_FISH_30939.jpg', 'INHS_FISH_54157.jpg', 'INHS_FISH_51172.jpg', 'INHS_FISH_48427.jpg', 'INHS_FISH_27196.jpg', 'INHS_FISH_109416.jpg', 'INHS_FISH_58837.jpg', 'INHS_FISH_025834.jpg', 'INHS_FISH_65024.jpg', 'INHS_FISH_57041.jpg', 'INHS_FISH_107186.jpg', 'INHS_FISH_107452.jpg', 'INHS_FISH_88250.jpg', 'INHS_FISH_4360.jpg', 'INHS_FISH_40727.jpg', 'INHS_FISH_74076.jpg', 'INHS_FISH_95097.jpg', 'INHS_FISH_22345.jpg', 'INHS_FISH_2257.jpg', 'INHS_FISH_46224.jpg', 'INHS_FISH_3003.jpg', 'INHS_FISH_46191.jpg', 'INHS_FISH_22213.jpg', 'INHS_FISH_67924.jpg', 'INHS_FISH_30732.jpg', 'INHS_FISH_51478.jpg', 'INHS_FISH_026243.jpg', 'INHS_FISH_27134.jpg', 'INHS_FISH_93908.jpg', 'INHS_FISH_4341.jpg', 'INHS_FISH_58745.jpg', 'INHS_FISH_108701.jpg', 'INHS_FISH_68083_2.jpg', 'INHS_FISH_64705.jpg', 'INHS_FISH_96551.jpg', 'INHS_FISH_62271.jpg', 'INHS_FISH_18909.jpg', 'INHS_FISH_47115.jpg', 'INHS_FISH_000835.jpg', 'INHS_FISH_26337.jpg', 'INHS_FISH_61785.jpg', 'INHS_FISH_106563.jpg', 'INHS_FISH_42303.jpg', 'INHS_FISH_80568.jpg', 'INHS_FISH_84222.jpg', 'INHS_FISH_87589.jpg', 'INHS_FISH_77457.jpg', 'INHS_FISH_75258.jpg', 'INHS_FISH_24127.jpg', 'INHS_FISH_40045.jpg', 'INHS_FISH_80646.jpg', 'INHS_FISH_30570.jpg', 'INHS_FISH_58870.jpg', 'INHS_FISH_104031.jpg', 'INHS_FISH_51418.jpg', 'INHS_FISH_95977.jpg', 'INHS_FISH_14454.jpg', 'INHS_FISH_33588.jpg', 'INHS_FISH_9578.jpg', 'INHS_FISH_2475.jpg', 'INHS_FISH_32267.jpg', 'INHS_FISH_5607.jpg', 'INHS_FISH_106224.jpg', 'INHS_FISH_48211.jpg', 'INHS_FISH_83473.jpg', 'INHS_FISH_2426.jpg']

# %% [markdown]
# Try to reload dataloader. You should get same indices.

# %%
train_loader, validation_loader, test_loader = datasetManager.getLoaders()

# %%
for batch in train_loader:
    print(batch['species'])
    print(batch['fileName'])
# Out:
# tensor([10,  9, 10,  6,  6,  0,  9,  6,  6, 10,  3,  3,  2,  0,  9,  5,  8, 10,
#         10,  2,  8,  1,  7,  5,  1,  2,  9,  8,  0,  5,  5,  2,  5,  1,  8,  6,
#          4,  0,  7,  4,  9,  4,  3,  4,  5,  3,  3,  4,  7,  4,  9,  1,  9,  5,
#          0,  5,  8,  7,  0,  8,  5,  8,  0, 10,  3,  9,  0,  4,  8,  0,  8, 10,
#          4,  0,  5,  5,  0,  1,  6,  2,  2,  0,  3,  8,  2,  1,  1,  9,  5,  1,
#          9, 10,  3,  1,  6,  0, 10,  3,  1, 10,  1,  6,  3, 10,  4,  4,  7,  4,
#         10,  6,  5,  9,  0,  1,  3,  2,  4,  2,  0,  4,  8,  0,  5,  5,  1,  1,
#          9,  4,  6,  9,  8,  0,  7,  1,  2,  0,  9,  5,  6,  6,  9,  2,  0,  8,
#          7,  7,  8,  6,  0,  5,  2,  7,  4,  8,  5,  8,  3,  8,  5,  4,  3,  9,
#          7,  8,  5,  8,  6,  5,  4,  4,  0,  4,  6,  0,  6,  3,  4, 10,  3, 10,
#          1, 10,  2,  0,  4,  2,  7,  5,  5,  0,  1,  7,  5,  6,  4,  8,  9,  7,
#          9,  1,  1,  8,  0, 10,  9,  6,  1,  6, 10, 10,  5,  7,  9, 10,  5,  5,
#          9, 10,  2,  8, 10,  3,  2,  3,  7,  1,  4,  5,  9, 10,  0, 10,  8,  8,
#          8,  7, 10, 10,  2,  2,  2,  3,  9,  9,  2,  1,  4,  2,  4,  1,  8,  3,
#          6,  2,  9,  7,  5,  2,  5,  2,  2, 10,  3,  1,  7,  7,  4,  7,  6,  2,
#          1,  8,  3,  6,  3,  5,  2,  1, 10,  6,  6,  3, 10,  9,  6,  1,  3, 10,
#          2,  6,  7,  5,  2,  6,  9,  0,  4,  7,  7,  2,  3,  6,  1,  4,  7,  9,
#          8,  3,  7,  8,  3,  9,  4, 10,  3,  7,  0,  3,  7,  3,  1,  0,  7,  1,
#          7,  4,  7,  6,  8,  7,  0,  2,  3, 10,  2,  8,  9,  6,  6,  9,  1,  9,
#          3, 10,  1,  0,  6,  4,  7,  0,  4,  8])
# ['INHS_FISH_90170.jpg', 'INHS_FISH_75145.jpg', 'INHS_FISH_75084.jpg', 'INHS_FISH_7390.jpg', 'INHS_FISH_8939.jpg', 'INHS_FISH_58884.jpg', 'INHS_FISH_2459.jpg', 'INHS_FISH_126.jpg', 'INHS_FISH_103738.jpg', 'INHS_FISH_31003.jpg', 'INHS_FISH_77561.jpg', 'INHS_FISH_24459.jpg', 'INHS_FISH_91459.jpg', 'INHS_FISH_79838.jpg', 'INHS_FISH_42897.jpg', 'INHS_FISH_99125.jpg', 'INHS_FISH_102495.jpg', 'INHS_FISH_38407.jpg', 'INHS_FISH_29741.jpg', 'INHS_FISH_831.jpg', 'INHS_FISH_5603.jpg', 'INHS_FISH_82727.jpg', 'INHS_FISH_21622.jpg', 'INHS_FISH_52208.jpg', 'INHS_FISH_59647.jpg', 'INHS_FISH_93450.jpg', 'INHS_FISH_9987.jpg', 'INHS_FISH_24644.jpg', 'INHS_FISH_30215.jpg', 'INHS_FISH_26197.jpg', 'INHS_FISH_30051.jpg', 'INHS_FISH_003822.jpg', 'INHS_FISH_79504.jpg', 'INHS_FISH_90219.jpg', 'INHS_FISH_91218.jpg', 'INHS_FISH_90944.jpg', 'INHS_FISH_90194.jpg', 'INHS_FISH_30228.jpg', 'INHS_FISH_46363.jpg', 'INHS_FISH_39616.jpg', 'INHS_FISH_48340.jpg', 'INHS_FISH_13110.jpg', 'INHS_FISH_23133.jpg', 'INHS_FISH_58949.jpg', 'INHS_FISH_44641.jpg', 'INHS_FISH_026052.jpg', 'INHS_FISH_12568.jpg', 'INHS_FISH_63373.jpg', 'INHS_FISH_82823.jpg', 'INHS_FISH_2237.jpg', 'INHS_FISH_88903.jpg', 'INHS_FISH_47027.jpg', 'INHS_FISH_64335.jpg', 'INHS_FISH_33220.jpg', 'INHS_FISH_68715.jpg', 'INHS_FISH_48411.jpg', 'INHS_FISH_429.jpg', 'INHS_FISH_56337.jpg', 'INHS_FISH_1587.jpg', 'INHS_FISH_6369.jpg', 'INHS_FISH_46916.jpg', 'INHS_FISH_11789.jpg', 'INHS_FISH_20690.jpg', 'INHS_FISH_35006.jpg', 'INHS_FISH_57055.jpg', 'INHS_FISH_94751.jpg', 'INHS_FISH_73804.jpg', 'INHS_FISH_5983.jpg', 'INHS_FISH_42772.jpg', 'INHS_FISH_105265.jpg', 'INHS_FISH_63287.jpg', 'INHS_FISH_58981.jpg', 'INHS_FISH_32343.jpg', 'INHS_FISH_89331.jpg', 'INHS_FISH_97321.jpg', 'INHS_FISH_92074.jpg', 'INHS_FISH_58562.jpg', 'INHS_FISH_41171.jpg', 'INHS_FISH_38018.jpg', 'INHS_FISH_95122.jpg', 'INHS_FISH_97141.jpg', 'INHS_FISH_95087.jpg', 'INHS_FISH_55256.jpg', 'INHS_FISH_109100.jpg', 'INHS_FISH_108235.jpg', 'INHS_FISH_75284.jpg', 'INHS_FISH_86895.jpg', 'INHS_FISH_53366.jpg', 'INHS_FISH_99121.jpg', 'INHS_FISH_51445.jpg', 'INHS_FISH_42717.jpg', 'INHS_FISH_76849.jpg', 'INHS_FISH_21342.jpg', 'INHS_FISH_40676.jpg', 'INHS_FISH_21565.jpg', 'INHS_FISH_98083.jpg', 'INHS_FISH_74127.jpg', 'INHS_FISH_17458.jpg', 'INHS_FISH_68432.jpg', 'INHS_FISH_29712.jpg', 'INHS_FISH_106363.jpg', 'INHS_FISH_56007.jpg', 'INHS_FISH_6398.jpg', 'INHS_FISH_74106.jpg', 'INHS_FISH_108140.jpg', 'INHS_FISH_106678.jpg', 'INHS_FISH_74573.jpg', 'INHS_FISH_46206.jpg', 'INHS_FISH_44694.jpg', 'INHS_FISH_6183.jpg', 'INHS_FISH_25498.jpg', 'INHS_FISH_108931.jpg', 'INHS_FISH_82719.jpg', 'INHS_FISH_59564.jpg', 'INHS_FISH_47774.jpg', 'INHS_FISH_012567.jpg', 'INHS_FISH_38963.jpg', 'INHS_FISH_25279.jpg', 'INHS_FISH_57501.jpg', 'INHS_FISH_45432.jpg', 'INHS_FISH_63588.jpg', 'INHS_FISH_23262.jpg', 'INHS_FISH_686.jpg', 'INHS_FISH_7459.jpg', 'INHS_FISH_51429.jpg', 'INHS_FISH_46991.jpg', 'INHS_FISH_9080.jpg', 'INHS_FISH_97992.jpg', 'INHS_FISH_917.jpg', 'INHS_FISH_96223.jpg', 'INHS_FISH_62299.jpg', 'INHS_FISH_58723.jpg', 'INHS_FISH_103344.jpg', 'INHS_FISH_50076.jpg', 'INHS_FISH_92825.jpg', 'INHS_FISH_30573.jpg', 'INHS_FISH_61200.jpg', 'INHS_FISH_4135.jpg', 'INHS_FISH_100772.jpg', 'INHS_FISH_59146.jpg', 'INHS_FISH_27397.jpg', 'INHS_FISH_91797.jpg', 'INHS_FISH_89111.jpg', 'INHS_FISH_85433.jpg', 'INHS_FISH_17910.jpg', 'INHS_FISH_104736.jpg', 'INHS_FISH_26400.jpg', 'INHS_FISH_105894.jpg', 'INHS_FISH_93371.jpg', 'INHS_FISH_99118.jpg', 'INHS_FISH_102092.jpg', 'INHS_FISH_81563.jpg', 'INHS_FISH_15451.jpg', 'INHS_FISH_85839.jpg', 'INHS_FISH_91048.jpg', 'INHS_FISH_87328.jpg', 'INHS_FISH_7471.jpg', 'INHS_FISH_37733.jpg', 'INHS_FISH_57050.jpg', 'INHS_FISH_9169.jpg', 'INHS_FISH_56375.jpg', 'INHS_FISH_64141.jpg', 'INHS_FISH_9051.jpg', 'INHS_FISH_1939.jpg', 'INHS_FISH_107230.jpg', 'INHS_FISH_100972.jpg', 'INHS_FISH_18547.jpg', 'INHS_FISH_99128.jpg', 'INHS_FISH_50741.jpg', 'INHS_FISH_32374.jpg', 'INHS_FISH_96891.jpg', 'INHS_FISH_25303.jpg', 'INHS_FISH_92623.jpg', 'INHS_FISH_20523.jpg', 'INHS_ ...

# %% [markdown]
# Plot information about the dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

suffix = str(params["suffix"]) if ("suffix" in params and params["suffix"] is not None) else ""

full_path = os.path.join(params["image_path"], suffix, "count_per_species.csv")
species_count_table = pd.read_csv(full_path).rename(columns={species_csv_fileName_header: "count"})
print(species_count_table)
species_count_table.plot.bar(x=species_csv_scientificName_header, y='count', rot=90, figsize=(25, 10))
plt.savefig(os.path.join(params["image_path"], suffix, "count_per_species.pdf"))
# Out:
#         scientificName  count
# 0    Carassius auratus     50
# 1      Cyprinus carpio     50
# 2      Esox americanus     50
# 3          Esox lucius     50
# 4      Lepomis auritus     50
# 5    Lepomis cyanellus     50
# 6   Noturus eleutherus     50
# 7       Noturus exilis     50
# 8       Noturus flavus     50
# 9      Noturus gyrinus     50
# 10    Noturus insignis     50

# %%
full_path = os.path.join(params["image_path"], suffix, "count_per_family_genis.csv")
family_genis_count_table = pd.read_csv(full_path).rename(columns={species_csv_fileName_header: "count"}).sort_values(by=['count'])
print(family_genis_count_table)
print(family_genis_count_table.groupby(species_csv_Family_header).agg('sum').sort_values(by=['count']))
family_genis_count_table.groupby(species_csv_Family_header).agg('sum').sort_values(by=['count']).plot.bar(rot=90, figsize=(15, 10))
plt.savefig(os.path.join(params["image_path"], suffix, 'count_per_family.pdf'))
family_genis_count_table.groupby(species_csv_Genus_header).agg('sum').sort_values(by=['count']).plot.bar(rot=90, figsize=(15, 10))
plt.savefig(os.path.join(params["image_path"], suffix, 'count_per_genis.pdf'))
# Out:
#           Family      Genus  count
# 1     Cyprinidae  Carassius     50
# 2     Cyprinidae   Cyprinus     50
# 0  Centrarchidae    Lepomis    100
# 3       Esocidae       Esox    100
# 4    Ictaluridae    Noturus    250
#                count
# Family
# Centrarchidae    100
# Cyprinidae       100
# Esocidae         100
# Ictaluridae      250

# %% [markdown]
# Get count matrix

# %%
import numpy as np
import seaborn as sns; sns.set()

cleaned_metadata = pd.read_csv(os.path.join(params["image_path"], suffix, cleaned_species_csv_fileName), sep='\t')
species_genis_matrix = cleaned_metadata.groupby([species_csv_scientificName_header, species_csv_Genus_header]).size().unstack(fill_value=0)

print(species_genis_matrix)
fig, ax = plt.subplots(figsize=(25,45))
sns.heatmap(species_genis_matrix, annot=True, fmt="d", ax=ax, cmap="YlGnBu", cbar=False)
plt.savefig(os.path.join(params["image_path"], suffix , 'species_genis_matrix.pdf'))
species_genis_matrix.to_csv(os.path.join(params["image_path"], suffix, 'species_genis_matrix.csv'), sep='\t')
# Out:
# Genus               Carassius  Cyprinus  Esox  Lepomis  Noturus
# scientificName
# Carassius auratus          50         0     0        0        0
# Cyprinus carpio             0        50     0        0        0
# Esox americanus             0         0    50        0        0
# Esox lucius                 0         0    50        0        0
# Lepomis auritus             0         0     0       50        0
# Lepomis cyanellus           0         0     0       50        0
# Noturus eleutherus          0         0     0        0       50
# Noturus exilis              0         0     0        0       50
# Noturus flavus              0         0     0        0       50
# Noturus gyrinus             0         0     0        0       50
# Noturus insignis            0         0     0        0       50

# %% [markdown]
# Get most frequent Genuses and clip them to a certain size

# %%
import os
for size in list_of_sizes_of_interest:
    sub_path = os.path.join(params["image_path"], str(size))
    if not os.path.exists(sub_path):
            os.makedirs(sub_path)
    # find species with image count more than a threshold
    genus_groupedby_species = cleaned_metadata.groupby([species_csv_Genus_header, species_csv_scientificName_header]).filter(lambda x: x[species_csv_fileName_header].count() >= size)
    genus_groupedby_species = genus_groupedby_species.groupby([species_csv_Genus_header, species_csv_scientificName_header]).agg(len).rename(columns={species_csv_fileName_header: "count"})['count']
    print("\nSpecies of sample size", size)
    print(genus_groupedby_species)
    # get n top for each species
    species_list = genus_groupedby_species.reset_index()['scientificName'].unique()
    trimmed_cleaned_metadata = cleaned_metadata.loc[cleaned_metadata[species_csv_scientificName_header].isin(species_list)].groupby(species_csv_scientificName_header).head(size)
    print(trimmed_cleaned_metadata)
    trimmed_cleaned_metadata.to_csv(os.path.join(sub_path, cleaned_species_csv_fileName), sep="\t", index=False)

# %% [markdown]
# Get image size statistics

# %%
import PIL
from PIL import Image

# Get params
data_root = params["image_path"]
suffix = str(params["suffix"]) if ("suffix" in params and params["suffix"] is not None) else ""

# Get file
cleaned_species_csv_fileName_withsuffix = cleaned_species_csv_fileName
cleaned_species_csv_fileName_full_path = os.path.join(data_root, suffix, cleaned_species_csv_fileName_withsuffix)
cleaned_species_csv_file_exists = os.path.exists(cleaned_species_csv_fileName_full_path)
species_csv = pd.read_csv(cleaned_species_csv_fileName_full_path, delimiter='\t', index_col=species_csv_fileName_header, usecols=species_csv_usedColumns)
img_count = len(species_csv.index)

# Get image sizes
width=[]
height=[]
for indx, row in species_csv.iterrows(): 
    image = PIL.Image.open(os.path.join(data_root,image_subpath,indx))
    w, h = image.size
    width.append(w)
    height.append(h)

# plot histogram
plt.figure(figsize=(10, 10))
plt.hist2d(width, height, bins=60)
plt.subplots_adjust(bottom=0, top=1, left=0, right=1)
plt.colorbar()
plt.show()

# %% [markdown]
# Print images per species (visual verification)

# %%
# %matplotlib inline

import math
import random

# Parameters: show images of certain species
species_index = speciesList
num_species = len(species_index)
print(species_index)
limit_per_species = 8
number_per_row = 8

img_indexes = []
for i in species_index:
    randomList = random.sample(dataset.getSpeciesIndices(i), k=limit_per_species)
    print(i, randomList)
    img_indexes = img_indexes + randomList
img_count = len(img_indexes)
# print(img_indexes)

# Plot

n_rows = math.ceil(img_count/number_per_row)
fig, axes = plt.subplots(n_rows, number_per_row, figsize=(15, 2.5*n_rows), dpi= 300)


out_index = 0
in_index = 0
for i, ax in enumerate(axes.flat):
    if i < img_count and i < limit_per_species*num_species:
        
        augmentation, normalization = dataset.toggle_image_loading(augmentation=False, normalization=False)
        obj = dataset[img_indexes[i]]
        image = obj["image"].squeeze()
        dataset.toggle_image_loading(augmentation, normalization)
        
        speciesName = dataset.getSpeciesOfIndex(obj["species"])
        ax.set_xlabel(speciesName)

        n_channels = params["n_channels"]
        if n_channels != 1:
                image = image.permute(1, 2, 0)
                
        ax.imshow(image.cpu().detach().numpy())
        ax.set_xticks([])
        ax.set_yticks([])
    else:
        break
        
fig.tight_layout(rect=[0, 0.03, 1, 0.95])
fig.show()
# Out:
# ['Lepomis cyanellus', 'Lepomis auritus', 'Carassius auratus', 'Cyprinus carpio', 'Esox americanus', 'Esox lucius', 'Noturus gyrinus', 'Noturus exilis', 'Noturus flavus', 'Noturus eleutherus', 'Noturus insignis']
# Lepomis cyanellus [406, 114, 110, 427, 433, 256, 488, 502]
# Lepomis auritus [58, 374, 57, 189, 412, 237, 169, 417]
# Carassius auratus [388, 300, 393, 11, 336, 231, 26, 42]
# Cyprinus carpio [315, 312, 223, 28, 497, 264, 29, 204]
# Esox americanus [436, 227, 411, 453, 152, 398, 217, 288]
# Esox lucius [23, 94, 355, 441, 233, 200, 99, 342]
# Noturus gyrinus [188, 33, 121, 438, 143, 468, 67, 485]
# Noturus exilis [248, 519, 325, 122, 257, 258, 178, 271]
# Noturus flavus [195, 68, 523, 536, 311, 19, 184, 155]
# Noturus eleutherus [13, 430, 527, 515, 284, 40, 31, 77]
# Noturus insignis [60, 208, 220, 347, 55, 327, 180, 504]
