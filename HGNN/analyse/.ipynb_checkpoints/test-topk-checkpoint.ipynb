# %% [markdown]
# import

# %%
# %matplotlib inline
import os
import torch

import matplotlib.pyplot as plt
import torchvision.models as models

# from flashtorch.utils import apply_transforms, load_image
# from flashtorch.saliency import Backprop

import dataLoader
from configParser import ConfigParser, getModelName

# %% [markdown]
# cuda

# %%
# CUDA support 
if torch.cuda.is_available():
    torch.cuda.set_device(0) # 0
    torch.set_default_tensor_type('torch.cuda.FloatTensor')
    print("We are using cuda")
# Out:
# We are using cuda

# %% [markdown]
# parameters

# %%
# params
experimentName = "test_22987_suffix50_11_CNN2_differentConfig_batchnorm"
experiment_index = 0
trial_index=2
experiment_type = "multi-trial"

# %% [markdown]
# importLoad experiment

# %%
from configParser import ConfigParser
config_parser = ConfigParser(experimentName)

experimentName = os.path.join(experimentName, experiment_type)
print(experimentName)
# Out:
# test_22987_suffix50_11_CNN2_differentConfig_batchnorm/multi-trial

# %% [markdown]
# load dataset

# %%
if experiment_type == "multi-trial" or experiment_type == "selected-multi-trial":
    if experiment_type == "multi-trial":
        paramsIterator = config_parser.getHyperpIter()
    else:
        paramsIterator = config_parser.getHyperpSelectedIter()
        
    for indx, e in enumerate(paramsIterator):
        if indx ==experiment_index:
            experiment_params = e
            break
            
elif experiment_type == "single-trial":
    experiment_params = config_parser.read()
else:
    raise


print(experiment_params)
# Out:
# {'image_path': '/data/BGNN_data/INHS_cropped', 'suffix': '50_11', 'training_count': 0.64, 'validation_count': 0.16, 'imageDimension': 224, 'n_channels': 3, 'augmentation': False, 'batchSize': 550, 'n_epochs': 4000, 'learning_rate': 0.01, 'numOfTrials': 10, 'patience': 100, 'useHeirarchy': True, 'useRelu': True, 'downsample': True, 'downsampleOutput': 200, 'takeFromIntermediate': True, 'takeFromIntermediateOutput': 200, 'fc_layers': 2, 'useAdam': False, 'resnet': '18', 'normalize': True, 'softmax': True, 'batchNormalize': True}

# %%
datasetManager = dataLoader.datasetManager(experimentName, True)
datasetManager.updateParams(experiment_params)
dataset = datasetManager.getDataset()
# Out:
# file /data/BGNN_data/INHS_cropped/50_11/test_22987_suffix50_11_CNN2_differentConfig_batchnorm/multi-trial/tc0.640000_vc0.160000_d224_c3_augFalse_nTrue/dataset.pkl read

# %% [markdown]
# Load model of a specific trial

# %%
import CNN

speciesList = dataset.getSpeciesList()
numberOfSpecies = len(speciesList)
genusList = dataset.getGenusList()
numberOfGenus = len(genusList)

trialName = experimentName
if experiment_type != "single-trial":
    trialName = os.path.join(experimentName, getModelName(experiment_params, trial_index))

architecture = {
    "species": numberOfSpecies,
    "genus" : numberOfGenus
}
model = CNN.create_model(architecture, experiment_params)
loss_list, accuracy_list, epochs, time_elapsed = CNN.loadModel(model, trialName)

# %% [markdown]
# Model wrapper

# %%
from flashtorch_modefied import CNN_wrapper, visualizeOverlay, visualizeHeatmap, Backprop

wrapped_model = CNN_wrapper(model, experiment_params)
backprop = Backprop(wrapped_model)

# %% [markdown]
# Show correctly classified examples

# %%
# param
enableCorrectlyClassifiedSpecies=False
example_list = [speciesList[0]] # [genusList[4]] # [speciesList[0]]
output_key="species"# "genus" # "species"
num_per_class = 50
number_per_row = 4
print(example_list)
# Out:
# ['Lepomis cyanellus']

# %%
import math

if enableCorrectlyClassifiedSpecies:

    # Only set either to true
    wrapped_model.setOutputsOfInterest({
        "species": True,
        "genus" : False
    })

    count = len(example_list)*num_per_class
    n_rows = math.ceil(count/number_per_row)
    fig, axes = plt.subplots(n_rows, number_per_row, figsize=(8, 2.5*n_rows), dpi= 300)

    indexingList = speciesList if output_key=="species" else genusList

    examples = []
    for i in example_list:
        class_ = indexingList.index(i)
        examples.append(dataLoader.getExamples(model, dataset, class_, class_, output_key, num_per_class))

    for i, ax in enumerate(axes.flat):
        if i < count:
            ExampleIndex = int(math.floor(i/num_per_class))
            className = example_list[ExampleIndex]
            class_ = indexingList.index(className)
            withinExampleClassIndex = i % num_per_class
            examplesSubList = examples[ExampleIndex]
            images = examplesSubList[withinExampleClassIndex] if withinExampleClassIndex < len(examplesSubList) else None
            if images is not None:
                image, predictionImage = images
                image_tensor = image.unsqueeze(0).cpu()
                predictionImage_tensor = predictionImage.unsqueeze(0).cpu()
                predictionImage_tensor.requires_grad = True
                overlay = visualizeOverlay(backprop, predictionImage_tensor, image_tensor, class_, guided=True, use_gpu=True)
                heatmap = visualizeHeatmap(backprop, predictionImage_tensor, class_, guided=True, use_gpu=True)

                ax.set_xlabel("Class: {0}".format(className))
                for j in range(len(overlay)):
                    image, cmap, alpha = overlay[j]
                    image2, cmap2, alpha2  = heatmap[j]
                    if j == 0:
                        image2 = torch.unsqueeze(image2, 2)
                        image2 = image2.repeat(1, 1, 3)

                    stitchedImage = torch.cat((image, image2), 1)

                    ax.imshow(stitchedImage.cpu().detach().numpy(), cmap=cmap, alpha=alpha)
                ax.set_xticks([])
                ax.set_yticks([])

    fig.suptitle("Saliency map of correctly classified " + output_key)
    fig.tight_layout(rect=[0, 0.03, 1, 0.95])
    fig.show()
    fig.savefig(os.path.join(experimentName,"SaliencyMap_Correct"+output_key+".pdf"))

# %% [markdown]
# Show correctly classified examples

# %%
# param
enableCorrectlyClassifiedGenus=False
example_list = [genusList[0]] # [genusList[4]] # [speciesList[0]]
output_key="genus"# "genus" # "species"
num_per_class = 6
number_per_row = 3
print(example_list)
# Out:
# ['Lepomis']

# %%
import math

if enableCorrectlyClassifiedGenus:
    
    # Only set either to true
    wrapped_model.setOutputsOfInterest({
        "species": False,
        "genus" : True
    })


    count = len(example_list)*num_per_class
    n_rows = math.ceil(count/number_per_row)
    fig, axes = plt.subplots(n_rows, number_per_row, figsize=(8, 2.5*n_rows), dpi= 300)

    indexingList = speciesList if output_key=="species" else genusList

    examples = []
    for i in example_list:
        class_ = indexingList.index(i)
        examples.append(dataLoader.getExamples(model, dataset, class_, class_, output_key, num_per_class))

    for i, ax in enumerate(axes.flat):
        if i < count:
            ExampleIndex = int(math.floor(i/num_per_class))
            className = example_list[ExampleIndex]
            class_ = indexingList.index(className)
            withinExampleClassIndex = i % num_per_class
            examplesSubList = examples[ExampleIndex]
            images = examplesSubList[withinExampleClassIndex] if withinExampleClassIndex < len(examplesSubList) else None
            if images is not None:
                image, predictionImage = images
                image_tensor = image.unsqueeze(0).cpu()
                predictionImage_tensor = predictionImage.unsqueeze(0).cpu()
                predictionImage_tensor.requires_grad = True
                overlay = visualizeOverlay(backprop, predictionImage_tensor, image_tensor, class_, guided=True, use_gpu=True)
                heatmap = visualizeHeatmap(backprop, predictionImage_tensor, class_, guided=True, use_gpu=True)

                ax.set_xlabel("Class: {0}".format(className))
                for j in range(len(overlay)):
                    image, cmap, alpha = overlay[j]
                    image2, cmap2, alpha2  = heatmap[j]
                    if j == 0:
                        image2 = torch.unsqueeze(image2, 2)
                        image2 = image2.repeat(1, 1, 3)

                    stitchedImage = torch.cat((image, image2), 1)

                    ax.imshow(stitchedImage.cpu().detach().numpy(), cmap=cmap, alpha=alpha)
                ax.set_xticks([])
                ax.set_yticks([])

    fig.suptitle("Saliency map of correctly classified " + output_key)
    fig.tight_layout(rect=[0, 0.03, 1, 0.95])
    fig.show()
    fig.savefig(os.path.join(experimentName,"SaliencyMap_Correct"+output_key+".pdf"))

# %% [markdown]
# Show incorrectly classified examples

# %%
# param
enableIncorrectlyClassifiedSpecies=False
example_list = [(speciesList[0], speciesList[1]), 
                (speciesList[0], speciesList[2]),
               (speciesList[0], speciesList[3]),
               (speciesList[0], speciesList[4]),
               (speciesList[0], speciesList[5]),
               (speciesList[0], speciesList[6]),
               (speciesList[0], speciesList[7]),
               (speciesList[0], speciesList[8]),
               (speciesList[0], speciesList[9]),
               (speciesList[0], speciesList[10]),]
output_key="species"
num_per_class = 9
number_per_row = 3
print(example_list)
# Out:
# [('Lepomis cyanellus', 'Lepomis auritus'), ('Lepomis cyanellus', 'Carassius auratus'), ('Lepomis cyanellus', 'Cyprinus carpio'), ('Lepomis cyanellus', 'Esox americanus'), ('Lepomis cyanellus', 'Esox lucius'), ('Lepomis cyanellus', 'Noturus gyrinus'), ('Lepomis cyanellus', 'Noturus exilis'), ('Lepomis cyanellus', 'Noturus flavus'), ('Lepomis cyanellus', 'Noturus eleutherus'), ('Lepomis cyanellus', 'Noturus insignis')]

# %%
if enableIncorrectlyClassifiedSpecies:

    # Only set either to true
    wrapped_model.setOutputsOfInterest({
        "species": True,
        "genus" : False
    })


    count = len(example_list)*num_per_class
    n_rows = math.ceil(count/number_per_row)
    fig, axes = plt.subplots(n_rows, number_per_row, figsize=(8, 2.5*n_rows), dpi= 300)

    indexingList = speciesList if output_key=="species" else genusList

    examples = []
    for i in example_list:
        className = i[0]
        classNameConfusedAs = i[1]
        class_ = indexingList.index(className)
        classConfusedAs_ = indexingList.index(classNameConfusedAs)
        examples.append(dataLoader.getExamples(model, dataset, class_, classConfusedAs_, output_key, num_per_class))

    for i, ax in enumerate(axes.flat):
        if i < count:
            ExampleIndex = int(math.floor(i/num_per_class))
            entry = example_list[ExampleIndex]
            className = entry[0]
            classNameConfusedAs = entry[1]
            class_ = indexingList.index(className)
            withinExampleClassIndex = i % num_per_class
            examplesSubList = examples[ExampleIndex]
            images = examplesSubList[withinExampleClassIndex] if withinExampleClassIndex < len(examplesSubList) else None
            if images is not None:
                image, predictionImage = images
                image_tensor = image.unsqueeze(0).cpu()
                predictionImage_tensor = predictionImage.unsqueeze(0).cpu()
                predictionImage_tensor.requires_grad = True
                overlay = visualizeOverlay(backprop, predictionImage_tensor, image_tensor, class_, guided=True, use_gpu=True)
                heatmap = visualizeHeatmap(backprop, predictionImage_tensor, class_, guided=True, use_gpu=True)

                ax.set_xlabel("Class: {0} \nconfused as \n{1}".format(className, classNameConfusedAs))
                for j in range(len(overlay)):
                    image, cmap, alpha = overlay[j]
                    image2, cmap2, alpha2  = heatmap[j]
                    if j == 0:
                        image2 = torch.unsqueeze(image2, 2)
                        image2 = image2.repeat(1, 1, 3)

                    stitchedImage = torch.cat((image, image2), 1)

                    ax.imshow(stitchedImage.cpu().detach().numpy(), cmap=cmap, alpha=alpha)
                ax.set_xticks([])
                ax.set_yticks([])

    fig.suptitle("Saliency map of incorrectly classified " + output_key)
    fig.tight_layout(rect=[0, 0.03, 1, 0.95])
    fig.show()
    fig.savefig(os.path.join(experimentName,"SaliencyMap_Confused"+output_key+".pdf"))

# %% [markdown]
# Saliency map of one image

# %%
# params

 # Only set either to true
saliencyMapOfAnImage = True
wrapped_model.setOutputsOfInterest({
    "species": True,
    "genus" : False
})
img_full_path="/data/BGNN_data/INHS_cropped/images"
fileName= 'INHS_FISH_32534_test2.jpg'# "INHS_FISH_85839.jpg" # "test_INHS_FISH_50076.jpg" # INHS_FISH_106556.jpg
class_ = 10# 8 # 1 # 0

# %%
import os
from torchvision import transforms as torchvision_transforms
from skimage import io

if saliencyMapOfAnImage:

    fig = plt.figure(figsize=(8, 2.5), dpi= 300)

    original = io.imread(os.path.join(img_full_path, fileName))

    augmentation, normalization = dataset.toggle_image_loading(augmentation=False, normalization=False)
    transforms = dataset.getTransforms()
    composedTransforms = torchvision_transforms.Compose(transforms)
    image = composedTransforms(original)
    augmentation, normalization = dataset.toggle_image_loading(augmentation, normalization)

    transforms = dataset.getTransforms()
    composedTransforms = torchvision_transforms.Compose(transforms)
    predictionImage = composedTransforms(original)

    if torch.cuda.is_available():
        image = image.cuda()
        predictionImage = predictionImage.cuda()

    image_tensor = image.unsqueeze(0).cpu()
    predictionImage_tensor = predictionImage.unsqueeze(0).cpu()
    predictionImage_tensor.requires_grad = True
    overlay = visualizeOverlay(backprop, predictionImage_tensor, image_tensor, class_, guided=True, use_gpu=True)
    heatmap = visualizeHeatmap(backprop, predictionImage_tensor, class_, guided=True, use_gpu=True)

    for j in range(len(overlay)):
        image, cmap, alpha = overlay[j]
        image2, cmap2, alpha2  = heatmap[j]
        if j == 0:
            image2 = torch.unsqueeze(image2, 2)
            image2 = image2.repeat(1, 1, 3)

        stitchedImage = torch.cat((image, image2), 1)

        plt.imshow(stitchedImage.cpu().detach().numpy(), cmap=cmap, alpha=alpha)
    plt.xticks([])
    plt.yticks([])

    fig.suptitle("Saliency map")
    fig.tight_layout(rect=[0, 0.03, 1, 0.95])
    fig.show()
    fig.savefig(os.path.join(experimentName,"SaliencyMap2.pdf"))
    
    import PlotNetwork

    layerName = "species"
    # "input": 
    # "intermediate_resent":
    # "genus_intermediate": 
    # "downsampled_features":
    # "genus": 
    # "species":
    activatins_rows = 1

    out = model(predictionImage_tensor.cuda())
    useHeirarchy = experiment_params["useHeirarchy"]
    if useHeirarchy:
        out = out["species"]

    PlotNetwork.plot_activations(model, layerName, predictionImage_tensor.cuda(), experimentName, experiment_params, layerName, activatins_rows)
# Out:
# Number of activations:  torch.Size([1, 11])

# %%
import pandas as pd

df = pd.DataFrame(columns=['file name', 'true', 'predicted'])

dataloader = torch.utils.data.DataLoader(dataset, batch_size=len(dataset))
predlist, lbllist = CNN.getLoaderPredictions(dataloader, model, experiment_params)
for i, lbl in enumerate(lbllist):
    prd = predlist[i]
    if(lbl != prd):
        s = dataset[i]
        df = df.append({'file name' : s['fileName'] , 'true' : int(lbl.cpu().numpy()), 'predicted' : int(prd.cpu().numpy())} , ignore_index=True)

df = df.sort_values('true')
df.to_pickle("hier")
print(df)
# Out:
#                file name true predicted
# 18   INHS_FISH_79838.jpg    0         1
# 31   INHS_FISH_93197.jpg    0         5
# 13    INHS_FISH_2401.jpg    0         5
# 12  INHS_FISH_104646.jpg    0         1
# 28   INHS_FISH_59400.jpg    1         0
# 25   INHS_FISH_51478.jpg    1         0
# 24   INHS_FISH_47068.jpg    1         0
# 32   INHS_FISH_88450.jpg    2         3
# 0    INHS_FISH_33737.jpg    2         3
# 7    INHS_FISH_88453.jpg    2         3
# 8   INHS_FISH_000710.jpg    2         3
# 23   INHS_FISH_84222.jpg    3         2
# 14   INHS_FISH_22345.jpg    3         4
# 2    INHS_FISH_45318.jpg    3         2
# 29  INHS_FISH_100521.jpg    3         2
# 19   INHS_FISH_95977.jpg    3         2
# 34    INHS_FISH_4360.jpg    4         5
# 11   INHS_FISH_32343.jpg    4         9
# 3   INHS_FISH_107971.jpg    4         9
# 22    INHS_FISH_8939.jpg    6        10
# 17   INHS_FISH_95253.jpg    6        10
# 30  INHS_FISH_105980.jpg    6        10
# ...

# %% [markdown]
# Top-k accuracy

# %%
def get_topk_dataframe(classType, lbllist, predlist):
    if classType=="genus":
        classes = range(numberOfGenus)
    else:
        classes = range(numberOfSpecies)

    df = pd.DataFrame(columns=[classType, 'count', 'top-1', 'top-2', 'top-3', 'top-4', 'top-5'])

    for class_ in classes:
        lbllist_idxs = (lbllist==class_).nonzero()[:,0]
        lbllist_sub = lbllist[lbllist_idxs, :]
        predlist_sub = predlist[lbllist_idxs, :]

        tops = CNN.top_k_acc(predlist_sub, lbllist_sub)
        df = df.append({classType : class_ , 
                        'count' : lbllist_sub.shape[0],
                        'top-1' : tops[0].cpu().numpy(), 
                        'top-2' : tops[1].cpu().numpy(),
                        'top-3' : tops[2].cpu().numpy(),
                        'top-4' : tops[3].cpu().numpy(),
                        'top-5' : tops[4].cpu().numpy(),
                        } , ignore_index=True)


    tops = CNN.top_k_acc(predlist, lbllist)
    df = df.append({classType : "Overall" , 
                    'count' : predlist.shape[0],
                    'top-1' : tops[0].cpu().numpy(), 
                    'top-2' : tops[1].cpu().numpy(),
                    'top-3' : tops[2].cpu().numpy(),
                    'top-4' : tops[3].cpu().numpy(),
                    'top-5' : tops[4].cpu().numpy(),
                    } , ignore_index=True)
    
    return df

# %%
def get_topk_withinRightGenus_dataframe(lbllist, predlist, dataset):
    df = pd.DataFrame(columns=['species', 'count', 'top-1', 'top-2', 'top-3', 'top-4', 'top-5'])

    numberOfSpecies = len(dataset.getSpeciesList())
    for class_ in range(numberOfSpecies):
        lbllist_idxs = (lbllist==class_).nonzero()[:,0]
        lbllist_sub = lbllist[lbllist_idxs, :]
        predlist_sub = predlist[lbllist_idxs, :]

        tops = CNN.top_k_acc_within_genus(predlist_sub, lbllist_sub, dataset)
        df = df.append({'species' : class_ , 
                        'count' : predlist_sub.shape[0],
                        'top-1' : tops[0].cpu().numpy(), 
                        'top-2' : tops[1].cpu().numpy(),
                        'top-3' : tops[2].cpu().numpy(),
                        'top-4' : tops[3].cpu().numpy(),
                        'top-5' : tops[4].cpu().numpy(),
                        } , ignore_index=True)

    tops = CNN.top_k_acc_within_genus(predlist, lbllist, dataset)
    df = df.append({'species' : "Overall" , 
                    'count' : predlist.shape[0],
                    'top-1' : tops[0].cpu().numpy(), 
                    'top-2' : tops[1].cpu().numpy(),
                    'top-3' : tops[2].cpu().numpy(),
                    'top-4' : tops[3].cpu().numpy(),
                    'top-5' : tops[4].cpu().numpy(),
                    } , ignore_index=True)

    return df

# %%
from IPython.display import display, HTML

train_loader, validation_loader, test_loader = datasetManager.getLoaders()

predlist_species, lbllist_species = CNN.getLoaderPredictionProbabilities(test_loader, model, experiment_params, label="species")
df_Species = get_topk_dataframe("species", lbllist_species, predlist_species)

predlist_genus, lbllist_genus = CNN.getLoaderPredictionProbabilities(test_loader, model, experiment_params, label="genus")
df_Genus = get_topk_dataframe("genus", lbllist_genus, predlist_genus)

display(HTML(df_Species.to_html()))
display(HTML(df_Genus.to_html()))
# Out:
# Loading saved dataloaders...
# file /data/BGNN_data/INHS_cropped/50_11/test_22987_suffix50_11_CNN2_differentConfig_batchnorm/multi-trial/tc0.640000_vc0.160000_d224_c3_augFalse_nTrue/trainingLoader.pkl read
# file /data/BGNN_data/INHS_cropped/50_11/test_22987_suffix50_11_CNN2_differentConfig_batchnorm/multi-trial/tc0.640000_vc0.160000_d224_c3_augFalse_nTrue/valLoader.pkl read
# file /data/BGNN_data/INHS_cropped/50_11/test_22987_suffix50_11_CNN2_differentConfig_batchnorm/multi-trial/tc0.640000_vc0.160000_d224_c3_augFalse_nTrue/testLoader.pkl read
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>species</th>
#       <th>count</th>
#       <th>top-1</th>
#       <th>top-2</th>
#       <th>top-3</th>
#       <th>top-4</th>
#       <th>top-5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>10</td>
#       <td>80.0</td>
#       <td>90.0</td>
#       <td>90.0</td>
# ...

# %%
df_Species_within_correct_genis = get_topk_withinRightGenus_dataframe(lbllist_species, predlist_species, dataset)

from IPython.display import display, HTML
display(HTML(df_Species_within_correct_genis.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>species</th>
#       <th>count</th>
#       <th>top-1</th>
#       <th>top-2</th>
#       <th>top-3</th>
#       <th>top-4</th>
#       <th>top-5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>10</td>
#       <td>90.0</td>
#       <td>90.0</td>
#       <td>90.0</td>
#       <td>90.0</td>
#       <td>100.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>10</td>
#       <td>100.0</td>
#       <td>100.0</td>
#       <td>100.0</td>
#       <td>100.0</td>
#       <td>100.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>10</td>
#       <td>80.0</td>
#       <td>100.0</td>
#       <td>100.0</td>
#       <td>100.0</td>
#       <td>100.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>10</td>
#       <td>80.0</td>
# ...
